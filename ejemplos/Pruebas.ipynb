# %%
aborn
import numpy as np
import seaborn as sns
import requests

# %%
doc = requests.get("https://github.com/dmolina/curso_python/blob/master/slides/ejemplos/propinas.xls?raw=true")

# %%
if doc.status_code == 200:
    with open("/tmp/tips.xls", 'wb') as file:
        for buffer in doc:
            file.write(buffer)

# %%
tips = pd.read_excel("https://github.com/dmolina/curso_python/blob/master/slides/ejemplos/propinas.xls?raw=true")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips);
# Out:
# /mnt/home/daniel/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:482: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])

# %%
tips.groupby("sex").max().plot(y="total_bill", kind="bar")

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tips.groupby("smoker").mean().plot(y="total_bill")

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.to_excel("propinas.xls")

# %%
titanic = sns.load_dataset("titanic")
titanic.to_excel("titanic.xls")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic[titanic['who']=='man']
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3  male  22.0      1      0    7.2500        S   Third
# 4           0       3  male  35.0      0      0    8.0500        S   Third
# 5           0       3  male   NaN      0      0    8.4583        Q   Third
# 6           0       1  male  54.0      0      0   51.8625        S   First
# 12          0       3  male  20.0      0      0    8.0500        S   Third
# 13          0       3  male  39.0      1      5   31.2750        S   Third
# 17          1       2  male   NaN      0      0   13.0000        S  Second
# 20          0       2  male  35.0      0      0   26.0000        S  Second
# 21          1       2  male  34.0      0      0   13.0000        S  Second
# 23          1       1  male  28.0      0      0   35.5000        S   First
# 26          0       3  male   NaN      0      0    7.2250        C   Third
# ...

# %%
import dplython

# %%
years = range(1880, 2011)
pieces = []
columns = ['name', 'sex', 'births']
for year in years:
    path = 'data/names/yob{}.txt'.format(year)
    #print(path)
    frame = pd.read_csv(path, names=columns)
    frame['year'] = year
    pieces.append(frame)
names = pd.concat(pieces, ignore_index=True)

def get_top1000(group):
    return group.sort_values(by='births', ascending=False)[:10]


grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
top1000.index = np.arange(len(top1000))
top1000[top1000['sex']=='M'].head()
# Out:
#        name sex  births  year
# 10     John   M    9655  1880
# 11  William   M    9532  1880
# 12    James   M    5927  1880
# 13  Charles   M    5348  1880
# 14   George   M    5126  1880

# %%
import numpy as np
import pandas as pd

years = range(1880, 2011)
pieces = []
columns = ['name', 'sex', 'births']
for year in years:
    path = 'data/names/yob{}.txt'.format(year)
    frame = pd.read_csv(path, names=columns)
    frame['year'] = year
    pieces.append(frame)
names = pd.concat(pieces, ignore_index=True)


def get_top1000(group):
    return group.sort_values(by='births', ascending=False)[:1000]


grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
top1000.index = np.arange(len(top1000))
top1000.head()
# Out:
#         name sex  births  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
def get_quantile_count(group, q=0.5):
    group = group.sort_values(by='births', ascending=False)
    return group.births.cumsum().values.searchsorted(q) + 1


diversity = top1000.groupby(['year', 'sex']).apply(get_quantile_count)
diversity = diversity.unstack('sex')
diversity.plot(title="Number of popular names in top 50%")
